# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("dsu1.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[323, 280], [325, 535], [765, 509], [761, 311]])

# Four corners of the book in destination image.
pts_dst = np.array([[323, 280], [323, 500], [725, 500], [725, 280]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("dsu2.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[180, 239], [180, 503], [822, 219], [820, 513]])

# Four corners of the book in destination image.
pts_dst = np.array([[180, 239], [180, 503], [750, 239], [750, 503]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("dsu3.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[106, 226], [110, 497], [706, 538], [703, 163]])

# Four corners of the book in destination image.
pts_dst = np.array([[100, 190], [100, 500], [700, 500], [700, 190]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("dsu4.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[239, 269], [238, 459], [565, 494], [570, 233]])

# Four corners of the book in destination image.
pts_dst = np.array([[250, 280], [250, 450], [550, 450], [550, 280]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

width_in_inches = 15
height_in_inches = 15
dots_per_inch = 70

f = plt.figure(
    figsize=(width_in_inches, height_in_inches),
    dpi=dots_per_inch)

f.add_subplot(1,2, 1)
plt.imshow(im)
plt.axis('off')
f.add_subplot(1,2, 2)
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread("dsu9.jpg")
im = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Four corners of the book in source image
pts_src = np.array([[395, 214], [649, 217], [397, 605], [640, 578]])

# Four corners of the book in destination image.
pts_dst = np.array([[400, 220], [650, 220], [400, 600], [650, 600]])

# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)

# Warp source image to destination based on homography
im2 = cv2.warpPerspective(im, h, (im.shape[1], im.shape[0]))

plt.axis('off')
plt.imshow(im)
plt.show()
plt.axis('off')
plt.imshow(im2)
plt.show()
